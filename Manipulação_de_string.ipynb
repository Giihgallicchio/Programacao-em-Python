# %% [markdown]
# <a href="https://colab.research.google.com/github/Giihgallicchio/Programacao-em-Python/blob/main/Manipula%C3%A7%C3%A3o_de_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#imprimindo texto por posição
texto = ' curso de python '
print(texto[2])
#apartir da 9 posição  até a posição 15
print(texto[9:15])
#apartir da 9 posição  até a posição 15, pulando de dois em dois
print(texto[9:15:2])
#do  inicio até a 8 posição
print(texto[:8])
#da 8 posição até a ultima
print(texto[8:])
#len verifica o tamanho do texto
print(len(texto))
# count conta quantas vezes aparece a plavra, caso não tenha retorna 0
print(texto.count('python'))
#find verifica se tem na frase e mostra a primeira posição
print(texto.find('python'))
#verifica se tem na frase e retorna True ou False
print('Python' in texto)
#subistitui a palavra antiga pela nova
print(texto.replace('python', 'Java'))
#todas a letras maiusculas
print(texto.upper())
#todas a letras minusculas
print(texto.lower())
#apenas a primeira maiuscula
print(texto.capitalize())
# a primeira de cada palavra maiuscula
print(texto.title())
#strip remove os espaços inuteis
print(texto.strip())
#rstrip remove os espaços inuteis da direita
print(texto.rstrip())
#lstrip remove os espaços inuteis da esquerda
print(texto.lstrip())
#adiciona o caracter no meio de cada caracter
print("+".join(texto))
#divide a frase em um array
print(texto.split())
#divide a frase em um array e mostra a ultima palavra
fraseDividida=texto.split()
print(fraseDividida[-1])
#encontra aultima vez que aparce a plavra python
print(texto.rfind('python'))

# %% [markdown]
# # Exercicios

# %%
# DESAFIO 22
# Crie um programa que leia o nome completo de uma pessoas e
# mostre
# O nome com todas as letras maiúsculas
# O nome com todas as letras minúsculas
# Quantas letras ao todo (sem considerar espaços)
# Quantas letras tem o primeiro nome

nome=input('Digite seu nome:\n')
print(f'O nome com  caixa alta {nome.upper()}')
print(f'O nome com  caixa baixa {nome.lower()}')
print('O tamanho do nome sem espaços: ',len(nome.replace(' ', ''))) # comentario
print('O tamanho do nome sem espaços: ',len(nome)-nome.count(' '))
nomedividido=nome.split()
print('O tamanho do primeiro nome: ',len(nomedividido[0]))
print('O tamanho do primeiro nome: ',nome.find(' '))

# %%
# DESAFIO 23
# Faça um programa que leia um numero de 0 a 9999 e mostre
# na tela cada um dos dígitos separados.
# Ex: Digite um numero: 1834
# Unidade: 4
# Dezena: 3
# Centena: 8
# Milhar: 1

numero=int(input('Digite o numero entre 0 e 9999:\n'))

unidade= numero % 10
dezena= (numero//10)%10
centena= (numero//100)%10
milhar= (numero//1000)%10
print(f'Numero: \nUnidade: {unidade}\nDezena: {dezena}'
      f'\nCentena: {centena}\nMilhar: {milhar}')

numero=input('digite um numero 0 a 9999')
print('milhar',numero[0:1])
print('centena',numero[1:2])
print('dezena',numero[2:3])
print('unidade',numero[3:4])

# %%
# DESAFIO 23
# Faça um programa que leia um numero de 0 a 9999 e mostre
# na tela cada um dos dígitos separados.
# Ex: Digite um numero: 1834
# Unidade: 4
# Dezena: 3
# Centena: 8
# Milhar: 1

numero=int(input('digite um numero'))
unidade=numero%10
dezena=(numero//10)%10
centena=(numero//100)%10
milhar=(numero//1000)%10
print('Unidade:',unidade)
print('Dezena: ',dezena)
print('Centena: ',centena)
print('Milhar: ',milhar)

# %%
# DESAFIO 24
# Crie um programa que leia o nome de uma cidade e diga se ela
# começa ou não com o nome "Santo“.

cidade=input('Digite o nome de uma cidade:\n').title()
print(f'cidade começa com santo?\n'
      f'{'Santo' in cidade[:5]}')

# %%
# DESAFIO 25
# Crie um programa que leia o nome de uma pessoa e diga se
# ela tem "Silva" no nome

nome=input('Digite o nome de uma pessoa:\n').lower()
print(f'Tem sila no nome da pessoa?\n'
      f'{'silva' in nome}')

# %%
# DESAFIO 26
# Faça um programa que leia uma frase pelo teclado e mostre:
# Quantas vezes aparece a letra "A"
# Em que posição ela aparece a primeira vez
# Em que posição ela aparece a ultima vez
frase='Faça um programa que leia uma frase pelo teclado e mostre'.upper()
print('Quantas vezes aparece a letra "A"?\n'
      f'{frase.count('A')}')
print('Em que posição ela aparece a primeira vez?\n'
      f'A primeira vez que a aparece a letra A é na posição {frase.find('A')+1}º')
print('Em que posição ela aparece a ultima vez?\n'
      f'A ultima vez que aparece a letra A é na posição {frase.rfind('A')+1}º')
