# %% [markdown]
# <a href="https://colab.research.google.com/github/Giihgallicchio/Programacao-em-Python/blob/main/Condicional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Escreva um programa que faça o computador “pensar” em um
# número int# DESAFIO 28
# inteiro entre 5 e 0 e peça para o usuário tentar
# descobrir qual foi o número escolhido pelo computador.

# O programa deverá escrever na tela se o usuário venceu ou
# perdeu.
import random

numeroPc=random.randint(0,5)
numeroJogador=int(input('Digite um numero inteiro: '))
if numeroPc == numeroJogador:
    print('acertou')
else:
    print('errou')

print('Acertou' if numeroPc == numeroJogador else 'Errou')

# %%
# DESAFIO 29
# Escreva um programa que leia a velocidade de um carro.
# Se ele ultrapassar 80km/h, mostre uma mensagem dizendo que
# ele foi multado.
# A multa vai custar R$ 7,00 por cada Km acima do limite.

velocida=float(input('Digite a velocidade: '))
if velocida > 80:
    print(f'O valor da multa é {(velocida-80)*7:,.2f}R$')

# %%
# DESAFIO 30
# Crie um programa que leia um número inteiro e mostre na tela
# se ele é PAR ou IMPAR.
num=int(input('Digite um numero: '))

print('Par' if num%2==0 else 'Impar')

if num%2==0:
    print('Par')
else:
    print('Impar')

# %%
# DESAFIO 31
# Desenvolva um programa que pergunte a distância de uma
# viagem em Km. Calcule o preço da passagem cobrando R$
# 0,50 por Km para viagens de até 200 Km e R$ 0,45 para
# viagens mais longas.
distancia=float(input('Digite a distancia: '))
print(f'O valor da viagem ficou {distancia*0.45:.2f}R$' if distancia>200
      else f'O valor da viagem ficou {distancia*0.5:.2f}R$')

if distancia <=200:
    preco=distancia*0.5
else:
    preco=distancia*0.45
print(f'O valor da viagem ficou {preco:.2f}R$')

# %%
# DESAFIO 32
# Faça um programa que leia um ano qualquer e mostre se ele é
# BISSEXTO.
# O ano bissexto ocorre a cada 4 anos (exceto em anos múltiplos
# de 100 que não são múltiplos de 400)

ano=int(input('Ano: '))
if ano%4==0:
    if ano%100==0 and ano%400!=0:
        print('Não é bisexto')
    else:
        print('Bisexto')
else:
    print('Não é bisexto')

#-------------------------------------------------------
if ano % 4 == 0 and ano % 100 != 0 or ano % 400 == 0:
print('O ano é bissexto')
else:
print('O ano não é bissexto')

# %%
num1=int(input('Digite um numero: '))
num2=int(input('Digite um numero: '))
num3=int(input('Digite um numero: '))

maior=num1
menor=num1

if num3 > maior:
    maior = num3
if num2 > maior:
    maior = num2
if num2 < menor:
    menor=num2
if num3 < menor:
    menor=num3
# ----------------------------------------------
print(max(num1,num2,num3))
print(min(num1,num2,num3))
print(maior)
print(menor)

# %%
# DESAFIO 34
# Escreva um programa que pergunte o salário de um funcionário
# e calcule o valor do seu aumento.
# Para salários superiores a R$ 1.250,00, calcule um aumento de
# 10%.
#
# Para salários inferiores ou iguais, o aumento é de 15%.
salario=float(input('Digite o salrio: '))
print(f'Novo salario: {(salario*0.10)+salario:,.2f}' if salario > 1250
      else f'Novo salario: {(salario*0.15)+salario:,.2f}')
# -----------------------------------------------------------------------
if salario > 1250:
    print(f'Novo salario: {(salario * 0.10) + salario:,.2f}')
else:
    print(f'Novo salario: {(salario * 0.15) + salario:,.2f}')

# %%
# DESAFIO 35
# Desenvolva um programa que leia o comprimento de três retas
# e diga ao usuário se elas podem ou não formar um triângulo.
#
# Condições Necessárias:
#
# a + b > c
# a + c > b
# b + c > a

reta1=int(input('Digite o valor da reta 1:\n'))
reta2=int(input('Digite o valor da reta 2:\n'))
reta3=int(input('Digite o valor da reta 3:\n'))

print(f'É um triangulo' if reta1+reta2>reta3
      and reta2+reta3> reta1 and reta3+ reta1>reta2
      else 'Não é um triangulo')
# -----------------------------------------------------------------------------
if reta1+reta2>reta3 and reta2+reta3> reta1 and reta3+ reta1>reta2:
    print('É um triangulo')
else:
    print('Não é um triangulo')

# %% [markdown]
# # Multiplas condições

# %%
# DESAFIO 36
# Escreva um programa para aprovar um empréstimo bancário para a
# compra de uma casa. O programa vai perguntar o valor da casa, o
# salário do comprador e em quantos anos ele vai pagar.
# Calcule o valor da prestação mensal, sabendo que ela não pode exceder
# 30% do salário ou então o empréstimo será negado.
valorCasa=float(input('Digite o valor da casa: '))
salario=float(input('Digite o salario: '))
tempo=int(input('Digite em quantos anos vai pagar: '))
tempo *= 12 # Isso é a mesma coisa: tempo = tempo * 12 -- quantidade de meses
salario *=0.3 # Isso é a mesma coisa: salario = salario * 0.3 -- 30% do salario
valorCasa/=tempo # Isso é a mesma coisa: valorCasa = valorCasa/ tempo -- Valor da parcela
if valorCasa > salario:
    print(f'Não foi aprovado!\n30% do salario: {salario:,.2f}'
          f'\nParcela: {valorCasa:,.2f}')
else:
    print(f'Financiamento aprovado\n30% do salario: {salario:,.2f}\n'
          f'Parcela: {valorCasa:,.2f}')

# %%
num=int(input('Digite um numero:\n'))
menu=input('1 - Binario\n2 - Hexdecimal'
           '\n3 - Octadecima\n\nDigite: ')
match menu:
    case menu if menu== '1' or menu=='5':
        print(bin(num)[2:])
        print(bin(num))
    case '2':
        print(f'\n{hex(num)[2:]}')
        print(hex(num))
    case '3':
        print(oct(num)[2:])
        print(oct(num))
    case _:
      print('Opção invalida')

# %%
# DESAFIO 38
# Escreva um programa que leia dois números inteiros e compare- os,
# mostrando na tela uma mensagem:
# O primeiro valor é maior
# O segundo valor é maior
# Não existe valor maior, os dois são iguais
numero1=int(input('Digite um numero: '))
numero2=int(input('Digite um numero: '))
if numero1>numero2:
    print(f'o maior é: {numero1}')
elif numero1 == numero2:
    print(f'São iguais')
else:
    print(f'O maior é: {numero2}')

# --------------------------------------------------------------------
print(f'O maior valor é {max(numero2,numero1)}' if numero1!=numero2
      else f'São iguais {numero2}')

# %%
# DESAFIO 39
# Faça um programa que leia o ano de nascimento de um jovem e
# informe, de acordo com sua idade:
# Se ele ainda vai se alistar ao serviço militar
# Se é a hora de se alistar
# Se já passou o tempo do alistamento
# Seu programa também deverá mostrar o tempo que falta ou que passou
# do prazo.
from datetime import date
idade=date.today().year-int(input('Digite o ano de nascimento: '))
if idade >18:
    print(f'Passo do alistamento.  {idade-18} anos.')
elif idade==18:
    print('É hora de se alistar!!')
else:
    print(f'Faltam {18-idade} anos para o alistamento')

# %%
# DESAFIO 41
# A confederação Nacional de Natação precisa de uma programa que leia
# o ano de nascimento de uma atleta e mostre sua categoria, de acordo
# com a idade.
# Até 9 anos: MIRIM
# Até 14 anos: INFANTIL
# Até 19 anos: JUNIOR
# Até 24 anos: SÊNIOR
# Acima: MASTER

from datetime import date
ano=int(input('Digite o ano de nascimento: '))
mes=int(input('Digite o mes de nascimento: '))
dia=int(input('Digite o dia di de nascimento: '))
aniversario=date(ano,mes,dia)
idade= int((date.today() -  aniversario).days /  365.2425)

if idade <= 9:
    print('Mirim')
elif idade <=14:
    print('Infantil')
elif idade <= 19:
    print('Junior')
elif idade <=24:
    print('Senior')
else:
    print('Master')

# %%
# DESAFIO 42
# Refaça o DESAFIO 35 dos triângulos, acrescentando o recurso
# de mostrar que tipo de triângulo será formado:
# Equilátero: Todos os lados iguais
# Isósceles: Dois lados iguais
# Escaleno: Todos os lados diferentes

lado1 = float(input('Digite o valor do lado 1'))
lado2 = float(input('Digite o valor do lado 2'))
lado3 = float(input('Digite o valor do lado 3'))
if lado1 + lado2 > lado3 and lado2 + lado3 > lado1 and lado3 + lado1 > lado2:
    if lado1==lado2==lado3:
        print('É um triangulo Equilatero')
    elif lado3==lado1 or lado2 == lado3 or lado2 == lado1:
        print('É um triangulo Isósceles')
    else:
        print('É um triangulo Escaleno')
else:
    print("Não forma um triangulo")

# %%
# DESAFIO 43
# Desenvolva uma lógica que leia o peso e a altura de uma
# pessoa, calcule seu IMC e mostre seu status, de acordo com a
# tabela abaixo:
# Abaixo de 18.5: Abaixo do Peso
# Entre 18.5 e 25: Peso ideal
# Entre 25 e 30: Sobrepeso
# Entre 30 e 40: Obesidade
# Acima de 40: Obesidade Mórbida

peso= float(input('Digite o seu peso'))
altura= float(input('Digite a sua altura'))
imc=peso/(altura**2)
if imc <=18.5:
    print(f'O seu imc é: {imc:.2f} e está abaixo do peso')
elif imc <=25:
    print(f'O seu imc é: {imc:.2f} e está com meso ideal do peso')
elif imc <=30:
    print(f'O seu imc é: {imc:.2f} e está com sobrepeso do peso')
elif imc <=40:
    print(f'O seu imc é: {imc:.2f} e está com obesidade do peso')
else:
    print(f'O seu imc é: {imc:.2f} e está com obesidade morbida do peso')

# %%
# DESAFIO 44
# Elabore um programa que calcule o valor a ser pago por um
# produto considerando o seu preço normal e condição de
# pagamento:
# Á vista dinheiro: 10% de desconto
# Á vista no cartão: 5% de desconto
# Em até 2x no cartão: Preço Normal
# 3x ou mais no cartão: 20% de juros

produto=float(input('Digite o valor do produto'))
pagamento=input('Selecione a forma de pagamento\n1 - Dinheiro\n2 - Debito\n3 - Crédito')
if pagamento == '1' or pagamento == 'Dinheiro':
    novo_valor= produto - (produto*0.10)
    print(f'Valor a ser pago é de {novo_valor:.2f}')
elif  pagamento == '2' or pagamento == 'Debito':
    novo_valor= produto-(produto*0.05)
    print(f'Valor a ser pago é de {novo_valor:.2f}')
elif  pagamento == '3' or pagamento == 'Crédito':
    qtda=int(input('Digite quantas vezes'))
    if qtda == 1:
        novo_valor= produto - (produto*0.05)
        print(f'Valor a ser pago é de {novo_valor:.2f}')
    elif qtda == 2:
        print(f'Valor a ser pago é de {produto:.2f}')
    else:
        novo_valor = produto + (produto * 0.20)
        print(f'Valor a ser pago é de {novo_valor:.2f}')
else:
    print("Selecione apenas uma das opções!!")

# %%
# DESAFIO 45
# Crie um programa que faça o computador jogar Jokenpô com você:

import random

jogador=input('"""JOKENPO"""\n\n1-Pedra\n2-Papel\n3-Tesoura\n\nEscolha: ').strip().title()
pc=random.choice(['Pedra','Papel','Tesoura'])
if (jogador=='Pedra' and pc=='Tesoura') or (jogador=='Tesoura' and pc=='Papel') or (jogador=='Papel' and pc=='Pedra'):
    print(f'Jogador {jogador} X {pc} Computador')
    print('Jogador venceu')
elif (jogador=='Papel' and pc=='Tesoura') or (jogador=='Pedra' and pc=='Papel') or (jogador=='Tesoura' and pc=='Pedra'):
    print(f'Jogador {jogador} X {pc} Computador')
    print('Computador venceu')
else:
    print(f'Jogador {jogador} X {pc} Computador')
    print('Empate')

# %%
# DESAFIO 54
# Crie um programa que leia o ano de nascimento de sete pessoas. No final, mostre
# quantas pessoas ainda não atingiram a maioridade e quantas já são maiores.
from datetime import date

menor=0
for x in range(7):
    ano=int(input('Digiete o ano de nascimento: '))
    mes=int(input('Digite o mes de nascimento: '))
    dia=int(input('Digite o dia do nascimento: '))
    data=date(ano,mes,dia)
    idade=int((date.today()-data).days / 365.2425)
    if idade < 18:
        menor+=1
print(f'Tem {menor} pessoas menores de idade.\n'
      f'tem {7-menor} pessoas maiores de idade ')

# %%
# DESAFIO 41
# A confederação Nacional de Natação precisa de uma programa que leia
# o ano de nascimento de uma atleta e mostre sua categoria, de acordo
# com a idade.
# Até 9 anos: MIRIM
# Até 14 anos: INFANTIL
# Até 19 anos: JUNIOR
# Até 24 anos: SÊNIOR
# Acima: MASTER
from datetime import date

idade=date.today().year-int(input('Ano de nascimento: '))
if idade < 5:
    print('Não a categorias')
elif idade <= 9:
    print('MIRIM')
elif idade<=14:
    print('INFANTIL')
elif idade <= 19:
    print('JUNIOR')
elif idade <=24:
    print('SÊNIOR')
else:
    print('Master')x
